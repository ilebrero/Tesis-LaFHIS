# %% [markdown]
# This script process statistics related to the experiments ran from the benchmark created
#
# TODO: Agregar urls, referencias, etc...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Atributes that are going to be considered for tracking during iterations

# %%
# Data that we'll keep track of

CLASES = [
    "org.openscience.cdk.index.CASNumber",
    "se.kth.cid.identity.ResourceURL",
    "se.kth.cid.identity.URI",
    "se.kth.cid.identity.URIClassifier",
    "se.kth.cid.identity.URIUtil",
    "se.kth.cid.identity.PathURN",
    "se.kth.cid.identity.URN",
    "se.kth.cid.identity.MIMEType",
    "stempeluhr.validation.TimeChecker",
    "org.jxpfw.util.InternationalBankAccountNumber",
    "org.jxpfw.util.CLocale",
    "com.prowidesoftware.swift.model.IBAN",
    "com.prowidesoftware.swift.model.BIC",
    "com.sun.jndi.toolkit.url.ConcreteURLContext",
    "java.util.regex.Pattern",
    "java.util.ArrayList",
    "org.apache.commons.cli.CommandLine",
    "org.jdom.Attribute",
    "org.apache.commons.codec.language.DoubleMetaphone",
    "org.joda.time.DateTime",
    "org.joda.time.format.DateTimeFormat",
    "org.jgrapht.alg.BellmanFordIterator",
    "org.apache.commons.math3.transform.FastFourierTransformer",
    "net.n3.nanoxml.XMLElement"
]

COLUMNS = [
    "Coverage",
    "AvgPathConditionLength",
    "Fitness",
    "MaxPathConditionLength",
    "MinPathConditionLength",
    "NumberOfPathsDiverged",
    "NumberOfPathsExplored",
    "NumberOfSATQueries"
    "NumberOfUsefulNewTests",
    "NumberOfTimeoutQueries",
    "NumberOfUNSATQueries",
    "NumberOfUnusefulNewTests",
    "Predicates",
    "Time_Check JUnit",
    "Time_Coverage Analysis",
    "Time_Done",
    "Time_Generating assertions",
    "Time_Initializing",
    "Time_Inlining",
    "Time_JUnit",
    "Time_Minimizing",
    "Time_Search",
    "Time_Statistics",
    "TotalNumberOfConstraints",
    "TotalTimeSpentExecutingConcolicaly",
    "TotalTimeSpentSolvingConstraints",
    "Total_Time"
]

# %% [markdown]
# Init of internal data representation
# ## Main idea
# For each tested class, track differences through iterations
# ## Structure
# Class -> attribute -> algorithm_version -> iteration value

# %%
data = dict()

for claz in CLASES:
    data[claz] = dict()
    
    for col in COLUMNS:
        data[claz][col] = dict()
        data[claz][col]["new_algorithm"] = []
        data[claz][col]["old_algorithm"] = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4aed55293f80> in <module>
#       1 data = dict()
#       2
# ----> 3 classes = prueba.loc[:, "TARGET_CLASS"]
#       4 for claz in classes:
#       5     data[claz] = dict()
#
# NameError: name 'prueba' is not defined

# %% [markdown]
# ## Data recolection

# %%
for iteration_index in range(1, 11):
    iteration_new_data = pd.read_csv(
        '../Benchmarks/clases_del_paper/repos/jars/report_new_algoritmo/statistics-iteration-{}.csv'
            .format(iteration_index)
    )
    iteration_old_data = pd.read_csv(
        '../Benchmarks/clases_del_paper/repos/jars/report_old_algoritmo/statistics-iteration-{}.csv'
            .format(iteration_index)
    )
    
    print(iteration_new_data.loc[:, "TARGET_CLASS"].to_numpy())
    print(iteration_new_data.loc[:, "TARGET_CLASS"].to_numpy())
    
    for index, claz in enumerate(CLASES):
        for col in COLUMNS:

            # If for any reason the experiment data is not there, we just skip it
            # TODO: why this may happen???             
            if (claz in iteration_old_data.loc[:, "TARGET_CLASS"].to_numpy() 
                and col in iteration_new_data.columns 
                and col in iteration_old_data.columns):
                data[claz][col]["new_algorithm"].append(
                    iteration_new_data.loc[index, col]
                )

                data[claz][col]["old_algorithm"].append(
                    iteration_old_data.loc[index, col]
                )
# Out:
# ['org.openscience.cdk.index.CASNumber' 'se.kth.cid.identity.ResourceURL'
#  'se.kth.cid.identity.URI' 'se.kth.cid.identity.URIClassifier'
#  'se.kth.cid.identity.PathURN' 'se.kth.cid.identity.URN'
#  'se.kth.cid.identity.MIMEType' 'stempeluhr.validation.TimeChecker'
#  'com.prowidesoftware.swift.model.IBAN'
#  'com.prowidesoftware.swift.model.BIC'
#  'org.apache.commons.cli.CommandLine'
#  'org.apache.commons.codec.language.DoubleMetaphone'
#  'org.openscience.cdk.index.CASNumber' 'se.kth.cid.identity.ResourceURL'
#  'se.kth.cid.identity.URI' 'se.kth.cid.identity.URIClassifier'
#  'se.kth.cid.identity.PathURN' 'se.kth.cid.identity.URN'
#  'se.kth.cid.identity.MIMEType' 'stempeluhr.validation.TimeChecker'
#  'com.prowidesoftware.swift.model.IBAN'
#  'com.prowidesoftware.swift.model.BIC'
#  'org.apache.commons.cli.CommandLine'
#  'org.apache.commons.codec.language.DoubleMetaphone'
#  'org.joda.time.format.DateTimeFormat'
#  'org.jgrapht.alg.BellmanFordIterator'
#  'org.apache.commons.math3.transform.FastFourierTransformer'
#  'net.n3.nanoxml.XMLElement']
# ['org.openscience.cdk.index.CASNumber' 'se.kth.cid.identity.ResourceURL'
#  'se.kth.cid.identity.URI' 'se.kth.cid.identity.URIClassifier'
#  'se.kth.cid.identity.PathURN' 'se.kth.cid.identity.URN'
#  'se.kth.cid.identity.MIMEType' 'stempeluhr.validation.TimeChecker'
#  'com.prowidesoftware.swift.model.IBAN'
#  'com.prowidesoftware.swift.model.BIC'
#  'org.apache.commons.cli.CommandLine'
#  'org.apache.commons.codec.language.DoubleMetaphone'
#  'org.openscience.cdk.index.CASNumber' 'se.kth.cid.identity.ResourceURL'
#  'se.kth.cid.identity.URI' 'se.kth.cid.identity.URIClassifier'
#  'se.kth.cid.identity.PathURN' 'se.kth.cid.identity.URN'
#  'se.kth.cid.identity.MIMEType' 'stempeluhr.validation.TimeChecker'
#  'com.prowidesoftware.swift.model.IBAN'
#  'com.prowidesoftware.swift.model.BIC'
#  'org.apache.commons.cli.CommandLine'
#  'org.apache.commons.codec.language.DoubleMetaphone'
#  'org.joda.time.format.DateTimeFormat'
#  'org.jgrapht.alg.BellmanFordIterator'
#  'org.apache.commons.math3.transform.FastFourierTransformer'
#  'net.n3.nanoxml.XMLElement']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-f8d7fa4d8efa> in <module>
#      21                 and col in iteration_new_data.columns
#      22                 and col in iteration_old_data.columns):
# ---> 23                 data[claz][col]["new_algorithm"].append(
#      24                     iteration_new_data.loc[index, col]
#      25                 )
#
# KeyError: 'org.openscience.cdk.index.CASNumber'

# %% [markdown]
# # Data showoff

# %%
data
# Out:
# {'org.openscience.cdk.index.CASNumber': {'Coverage': {'new_algorithm': [0.3636363636363637,
#     0.3636363636363637],
#    'old_algorithm': [0.2, 0.6100217864923747]},
#   'AvgPathConditionLength': {'new_algorithm': [1.5, 1.5],
#    'old_algorithm': [0.0, 0.0]},
#   'Fitness': {'new_algorithm': [8.433333333333334, 8.433333333333334],
#    'old_algorithm': [11.25, 152.96646746798575]},
#   'MaxPathConditionLength': {'new_algorithm': [2, 2], 'old_algorithm': [0, 0]},
#   'MinPathConditionLength': {'new_algorithm': [1, 1], 'old_algorithm': [0, 0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [1, 1], 'old_algorithm': [0, 0]},
#   'NumberOfPathsExplored': {'new_algorithm': [2, 2], 'old_algorithm': [0, 0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [1, 1], 'old_algorithm': [0, 0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [0, 0],
#    'old_algorithm': [0, 0]},
#   'Predicates': {'new_algorithm': [7, 7], 'old_algorithm': [7, 218]},
#   'Time_Check JUnit': {'new_algorithm': [1142, 934],
#    'old_algorithm': [754, 19448]},
#   'Time_Coverage Analysis': {'new_algorithm': [33, 42],
#    'old_algorithm': [28, 174]},
#   'Time_Done': {'new_algorithm': [1, 2], 'old_algorithm': [1, 0]},
#   'Time_Generating assertions': {'new_algorithm': [246, 201],
#    'old_algorithm': [194, 36605]},
#   'Time_Initializing': {'new_algorithm': [110, 68],
#    'old_algorithm': [76, 1857]},
#   'Time_Inlining': {'new_algorithm': [15, 11], 'old_algorithm': [5, 939]},
#   'Time_JUnit': {'new_algorithm': [26, 17], 'old_algorithm': [12, 25]},
#   'Time_Minimizing': {'new_algorithm': [46, 44], 'old_algorithm': [45, 2795]},
#   'Time_Search': {'new_algorithm': [1031, 745], 'old_algorithm': [741, 62858]},
#   'Time_Statistics': {'new_algorithm': [26, 21], 'old_algorithm': [15, 27]},
#   'TotalNumberOfConstraints': {'new_algorithm': [2, 2],
#    'old_algorithm': [0, 0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [175, 131],
#    'old_algorithm': [11, 12392]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0, 0],
#    'old_algorithm': [0, 0]},
#   'Total_Time': {'new_algorithm': [2777, 2187],
#    'old_algorithm': [1972, 124832]}},
#  'se.kth.cid.identity.ResourceURL': {'Coverage': {'new_algorithm': [0.0, 0.0],
#    'old_algorithm': [0.0, 0.0]},
#   'AvgPathConditionLength': {'new_algorithm': [0.0, 0.0],
#    'old_algorithm': [0.0, 0.0]},
#   'Fitness': {'new_algorithm': [0.0, 0.0], 'old_algorithm': [15.0, 55.0]},
#   'MaxPathConditionLength': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'MinPathConditionLength': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfPathsExplored': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [0, 0],
#    'old_algorithm': [0, 0]},
#   'Predicates': {'new_algorithm': [5, 5], 'old_algorithm': [5, 18]},
#   'Time_Check JUnit': {'new_algorithm': [1, 2], 'old_algorithm': [12, 3]},
#   'Time_Coverage Analysis': {'new_algorithm': [10, 20],
#    'old_algorithm': [20, 71]},
#   'Time_Done': {'new_algorithm': [2, 1], 'old_algorithm': [1, 2]},
#   'Time_Generating assertions': {'new_algorithm': [240, 216],
#    'old_algorithm': [253, 370]},
#   'Time_Initializing': {'new_algorithm': [83, 88], 'old_algorithm': [99, 861]},
#   'Time_Inlining': {'new_algorithm': [1, 2], 'old_algorithm': [2, 2]},
#   'Time_JUnit': {'new_algorithm': [45, 43], 'old_algorithm': [27, 53]},
#   'Time_Minimizing': {'new_algorithm': [33, 35], 'old_algorithm': [24, 67]},
#   'Time_Search': {'new_algorithm': [85, 99], 'old_algorithm': [101, 103]},
#   'Time_Statistics': {'new_algorithm': [26, 21], 'old_algorithm': [18, 24]},
#   'TotalNumberOfConstraints': {'new_algorithm': [0, 0],
#    'old_algorithm': [0, 0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [0, 0],
#    'old_algorithm': [0, 0]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0, 0],
#    'old_algorithm': [0, 0]},
#   'Total_Time': {'new_algorithm': [626, 628], 'old_algorithm': [658, 1657]}},
#  'se.kth.cid.identity.URI': {'Coverage': {'new_algorithm': [0.0, 0.0],
#    'old_algorithm': [0.0, 0.0]},
#   'AvgPathConditionLength': {'new_algorithm': [0.0, 0.0],
#    'old_algorithm': [0.0, 0.0]},
#   'Fitness': {'new_algorithm': [0.0, 0.0], 'old_algorithm': [56.0, 110.0]},
#   'MaxPathConditionLength': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'MinPathConditionLength': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfPathsExplored': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [0, 0],
#    'old_algorithm': [0, 0]},
#   'Predicates': {'new_algorithm': [22, 22], 'old_algorithm': [22, 47]},
#   'Time_Check JUnit': {'new_algorithm': [1, 13], 'old_algorithm': [2, 22]},
#   'Time_Coverage Analysis': {'new_algorithm': [9, 24],
#    'old_algorithm': [22, 56]},
#   'Time_Done': {'new_algorithm': [1, 2], 'old_algorithm': [1, 1]},
#   'Time_Generating assertions': {'new_algorithm': [195, 199],
#    'old_algorithm': [264, 554]},
#   'Time_Initializing': {'new_algorithm': [103, 101],
#    'old_algorithm': [97, 908]},
#   'Time_Inlining': {'new_algorithm': [1, 3], 'old_algorithm': [1, 1]},
#   'Time_JUnit': {'new_algorithm': [27, 39], 'old_algorithm': [28, 73]},
#   'Time_Minimizing': {'new_algorithm': [131, 164], 'old_algorithm': [54, 100]},
#   'Time_Search': {'new_algorithm': [83, 87], 'old_algorithm': [65, 994]},
#   'Time_Statistics': {'new_algorithm': [27, 28], 'old_algorithm': [20, 34]},
#   'TotalNumberOfConstraints': {'new_algorithm': [0, 0],
#    'old_algorithm': [0, 0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [0, 0],
#    'old_algorithm': [0, 12]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0, 0],
#    'old_algorithm': [0, 0]},
#   'Total_Time': {'new_algorithm': [679, 761], 'old_algorithm': [655, 2846]}},
#  'se.kth.cid.identity.URIClassifier': {'Coverage': {'new_algorithm': [0.631578947368421,
#     0.631578947368421],
#    'old_algorithm': [0.5, 0.0]},
#   'AvgPathConditionLength': {'new_algorithm': [5.461538461538463, 4.8125],
#    'old_algorithm': [0.0, 0.0]},
#   'Fitness': {'new_algorithm': [13.599999957746329, 13.599999957746329],
#    'old_algorithm': [15.166666664260747, 193.0]},
#   'MaxPathConditionLength': {'new_algorithm': [11, 11],
#    'old_algorithm': [0, 0]},
#   'MinPathConditionLength': {'new_algorithm': [1, 1], 'old_algorithm': [0, 0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [10, 6], 'old_algorithm': [0, 0]},
#   'NumberOfPathsExplored': {'new_algorithm': [18, 14],
#    'old_algorithm': [0, 0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0, 0], 'old_algorithm': [0, 0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [16, 10], 'old_algorithm': [0, 0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [8, 4],
#    'old_algorithm': [0, 0]},
#   'Predicates': {'new_algorithm': [13, 13], 'old_algorithm': [13, 68]},
#   'Time_Check JUnit': {'new_algorithm': [1480, 1231],
#    'old_algorithm': [1395, 1]},
#   'Time_Coverage Analysis': {'new_algorithm': [37, 40],
#    'old_algorithm': [30, 23]},
#   'Time_Done': {'new_algorithm': [6, 1], 'old_algorithm': [2, 0]},
#   'Time_Generating assertions': {'new_algorithm': [546, 507],
#    'old_algorithm': [455, 346]},
#   'Time_Initializing': {'new_algorithm': [119, 95],
#    'old_algorithm': [99, 145]},
#   'Time_Inlining': {'new_algorithm': [34, 36], 'old_algorithm': [38, 2]},
#   'Time_JUnit': {'new_algorithm': [29, 24], 'old_algorithm': [21, 30]},
#   'Time_Minimizing': {'new_algorithm': [111, 91], 'old_algorithm': [78, 224]},
#   'Time_Search': {'new_algorithm': [1150, 948], 'old_algorithm': [1093, 86]},
#   'Time_Statistics': {'new_algorithm': [33, 33], 'old_algorithm': [44, 22]},
#   'TotalNumberOfConstraints': {'new_algorithm': [26, 16],
#    'old_algorithm': [0, 0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [118, 95],
#    'old_algorithm': [107, 0]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0, 0],
#    'old_algorithm': [0, 0]},
#   'Total_Time': {'new_algorithm': [3680, 3107], 'old_algorithm': [3356, 981]}},
#  'se.kth.cid.identity.PathURN': {'Coverage': {'new_algorithm': [0.0, 0.0],
#    'old_algorithm': [0.0]},
#   'AvgPathConditionLength': {'new_algorithm': [0.0], 'old_algorithm': [0.0]},
#   'Fitness': {'new_algorithm': [0.0], 'old_algorithm': [12.0]},
#   'MaxPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'MinPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsExplored': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'Predicates': {'new_algorithm': [4], 'old_algorithm': [4]},
#   'Time_Check JUnit': {'new_algorithm': [2], 'old_algorithm': [2]},
#   'Time_Coverage Analysis': {'new_algorithm': [8], 'old_algorithm': [18]},
#   'Time_Done': {'new_algorithm': [4], 'old_algorithm': [0]},
#   'Time_Generating assertions': {'new_algorithm': [204],
#    'old_algorithm': [197]},
#   'Time_Initializing': {'new_algorithm': [159], 'old_algorithm': [110]},
#   'Time_Inlining': {'new_algorithm': [2], 'old_algorithm': [1]},
#   'Time_JUnit': {'new_algorithm': [34], 'old_algorithm': [24]},
#   'Time_Minimizing': {'new_algorithm': [24], 'old_algorithm': [19]},
#   'Time_Search': {'new_algorithm': [107], 'old_algorithm': [70]},
#   'Time_Statistics': {'new_algorithm': [40], 'old_algorithm': [14]},
#   'TotalNumberOfConstraints': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'Total_Time': {'new_algorithm': [686], 'old_algorithm': [556]}},
#  'se.kth.cid.identity.URN': {'Coverage': {'new_algorithm': [0.0],
#    'old_algorithm': [0.0]},
#   'AvgPathConditionLength': {'new_algorithm': [0.0], 'old_algorithm': [0.0]},
#   'Fitness': {'new_algorithm': [0.0], 'old_algorithm': [13.0]},
#   'MaxPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'MinPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsExplored': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'Predicates': {'new_algorithm': [4], 'old_algorithm': [4]},
#   'Time_Check JUnit': {'new_algorithm': [1], 'old_algorithm': [2]},
#   'Time_Coverage Analysis': {'new_algorithm': [8], 'old_algorithm': [19]},
#   'Time_Done': {'new_algorithm': [5], 'old_algorithm': [1]},
#   'Time_Generating assertions': {'new_algorithm': [226],
#    'old_algorithm': [229]},
#   'Time_Initializing': {'new_algorithm': [91], 'old_algorithm': [86]},
#   'Time_Inlining': {'new_algorithm': [1], 'old_algorithm': [1]},
#   'Time_JUnit': {'new_algorithm': [27], 'old_algorithm': [26]},
#   'Time_Minimizing': {'new_algorithm': [21], 'old_algorithm': [30]},
#   'Time_Search': {'new_algorithm': [79], 'old_algorithm': [106]},
#   'Time_Statistics': {'new_algorithm': [29], 'old_algorithm': [13]},
#   'TotalNumberOfConstraints': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'Total_Time': {'new_algorithm': [589], 'old_algorithm': [615]}},
#  'se.kth.cid.identity.MIMEType': {'Coverage': {'new_algorithm': [0.0],
#    'old_algorithm': [0.0]},
#   'AvgPathConditionLength': {'new_algorithm': [0.0], 'old_algorithm': [0.0]},
#   'Fitness': {'new_algorithm': [0.0], 'old_algorithm': [15.0]},
#   'MaxPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'MinPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsExplored': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'Predicates': {'new_algorithm': [4], 'old_algorithm': [4]},
#   'Time_Check JUnit': {'new_algorithm': [3], 'old_algorithm': [1]},
#   'Time_Coverage Analysis': {'new_algorithm': [9], 'old_algorithm': [28]},
#   'Time_Done': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'Time_Generating assertions': {'new_algorithm': [220],
#    'old_algorithm': [139]},
#   'Time_Initializing': {'new_algorithm': [95], 'old_algorithm': [100]},
#   'Time_Inlining': {'new_algorithm': [2], 'old_algorithm': [1]},
#   'Time_JUnit': {'new_algorithm': [23], 'old_algorithm': [121]},
#   'Time_Minimizing': {'new_algorithm': [31], 'old_algorithm': [27]},
#   'Time_Search': {'new_algorithm': [101], 'old_algorithm': [84]},
#   'Time_Statistics': {'new_algorithm': [18], 'old_algorithm': [15]},
#   'TotalNumberOfConstraints': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'Total_Time': {'new_algorithm': [603], 'old_algorithm': [617]}},
#  'stempeluhr.validation.TimeChecker': {'Coverage': {'new_algorithm': [0.0],
#    'old_algorithm': [0.0]},
#   'AvgPathConditionLength': {'new_algorithm': [0.0], 'old_algorithm': [0.0]},
#   'Fitness': {'new_algorithm': [0.0], 'old_algorithm': [12.0]},
#   'MaxPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'MinPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsExplored': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'Predicates': {'new_algorithm': [5], 'old_algorithm': [5]},
#   'Time_Check JUnit': {'new_algorithm': [2], 'old_algorithm': [1]},
#   'Time_Coverage Analysis': {'new_algorithm': [20], 'old_algorithm': [30]},
#   'Time_Done': {'new_algorithm': [1], 'old_algorithm': [0]},
#   'Time_Generating assertions': {'new_algorithm': [238],
#    'old_algorithm': [225]},
#   'Time_Initializing': {'new_algorithm': [71], 'old_algorithm': [78]},
#   'Time_Inlining': {'new_algorithm': [4], 'old_algorithm': [3]},
#   'Time_JUnit': {'new_algorithm': [31], 'old_algorithm': [53]},
#   'Time_Minimizing': {'new_algorithm': [34], 'old_algorithm': [41]},
#   'Time_Search': {'new_algorithm': [104], 'old_algorithm': [96]},
#   'Time_Statistics': {'new_algorithm': [19], 'old_algorithm': [32]},
#   'TotalNumberOfConstraints': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'Total_Time': {'new_algorithm': [625], 'old_algorithm': [660]}},
#  'com.prowidesoftware.swift.model.IBAN': {'Coverage': {'new_algorithm': [0.038461538461538464],
#    'old_algorithm': [0.06521739130434782]},
#   'AvgPathConditionLength': {'new_algorithm': [0.0], 'old_algorithm': [0.0]},
#   'Fitness': {'new_algorithm': [35.98684210526316], 'old_algorithm': [50.0]},
#   'MaxPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'MinPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsExplored': {'new_algorithm': [3], 'old_algorithm': [0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'Predicates': {'new_algorithm': [19], 'old_algorithm': [19]},
#   'Time_Check JUnit': {'new_algorithm': [1387], 'old_algorithm': [1519]},
#   'Time_Coverage Analysis': {'new_algorithm': [53], 'old_algorithm': [41]},
#   'Time_Done': {'new_algorithm': [1], 'old_algorithm': [0]},
#   'Time_Generating assertions': {'new_algorithm': [247],
#    'old_algorithm': [318]},
#   'Time_Initializing': {'new_algorithm': [231], 'old_algorithm': [297]},
#   'Time_Inlining': {'new_algorithm': [34], 'old_algorithm': [8]},
#   'Time_JUnit': {'new_algorithm': [22], 'old_algorithm': [35]},
#   'Time_Minimizing': {'new_algorithm': [78], 'old_algorithm': [86]},
#   'Time_Search': {'new_algorithm': [716], 'old_algorithm': [783]},
#   'Time_Statistics': {'new_algorithm': [26], 'old_algorithm': [30]},
#   'TotalNumberOfConstraints': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [19],
#    'old_algorithm': [17]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'Total_Time': {'new_algorithm': [2896], 'old_algorithm': [3219]}},
#  'com.prowidesoftware.swift.model.BIC': {'Coverage': {'new_algorithm': [0.0],
#    'old_algorithm': [0.0]},
#   'AvgPathConditionLength': {'new_algorithm': [0.0], 'old_algorithm': [0.0]},
#   'Fitness': {'new_algorithm': [0.0], 'old_algorithm': [116.0]},
#   'MaxPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'MinPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsExplored': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'Predicates': {'new_algorithm': [43], 'old_algorithm': [43]},
#   'Time_Check JUnit': {'new_algorithm': [1], 'old_algorithm': [3]},
#   'Time_Coverage Analysis': {'new_algorithm': [18], 'old_algorithm': [29]},
#   'Time_Done': {'new_algorithm': [9], 'old_algorithm': [0]},
#   'Time_Generating assertions': {'new_algorithm': [231],
#    'old_algorithm': [193]},
#   'Time_Initializing': {'new_algorithm': [199], 'old_algorithm': [132]},
#   'Time_Inlining': {'new_algorithm': [3], 'old_algorithm': [2]},
#   'Time_JUnit': {'new_algorithm': [27], 'old_algorithm': [27]},
#   'Time_Minimizing': {'new_algorithm': [86], 'old_algorithm': [226]},
#   'Time_Search': {'new_algorithm': [245], 'old_algorithm': [106]},
#   'Time_Statistics': {'new_algorithm': [28], 'old_algorithm': [23]},
#   'TotalNumberOfConstraints': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'Total_Time': {'new_algorithm': [948], 'old_algorithm': [843]}},
#  'org.apache.commons.cli.CommandLine': {'Coverage': {'new_algorithm': [0.0],
#    'old_algorithm': [0.0]},
#   'AvgPathConditionLength': {'new_algorithm': [0.0], 'old_algorithm': [0.0]},
#   'Fitness': {'new_algorithm': [0.0], 'old_algorithm': [60.0]},
#   'MaxPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'MinPathConditionLength': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfPathsExplored': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'Predicates': {'new_algorithm': [18], 'old_algorithm': [18]},
#   'Time_Check JUnit': {'new_algorithm': [1], 'old_algorithm': [1]},
#   'Time_Coverage Analysis': {'new_algorithm': [22], 'old_algorithm': [112]},
#   'Time_Done': {'new_algorithm': [2], 'old_algorithm': [0]},
#   'Time_Generating assertions': {'new_algorithm': [167],
#    'old_algorithm': [157]},
#   'Time_Initializing': {'new_algorithm': [160], 'old_algorithm': [165]},
#   'Time_Inlining': {'new_algorithm': [1], 'old_algorithm': [1]},
#   'Time_JUnit': {'new_algorithm': [38], 'old_algorithm': [33]},
#   'Time_Minimizing': {'new_algorithm': [147], 'old_algorithm': [70]},
#   'Time_Search': {'new_algorithm': [94], 'old_algorithm': [99]},
#   'Time_Statistics': {'new_algorithm': [22], 'old_algorithm': [18]},
#   'TotalNumberOfConstraints': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'Total_Time': {'new_algorithm': [755], 'old_algorithm': [758]}},
#  'org.apache.commons.codec.language.DoubleMetaphone': {'Coverage': {'new_algorithm': [0.0],
#    'old_algorithm': [0.0]},
#   'AvgPathConditionLength': {'new_algorithm': [1.5], 'old_algorithm': [0.0]},
#   'Fitness': {'new_algorithm': [435.9977777777778], 'old_algorithm': [534.0]},
#   'MaxPathConditionLength': {'new_algorithm': [2], 'old_algorithm': [0]},
#   'MinPathConditionLength': {'new_algorithm': [1], 'old_algorithm': [0]},
#   'NumberOfPathsDiverged': {'new_algorithm': [2], 'old_algorithm': [0]},
#   'NumberOfPathsExplored': {'new_algorithm': [3], 'old_algorithm': [0]},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUNSATQueries': {'new_algorithm': [0], 'old_algorithm': [0]},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [2], 'old_algorithm': [0]},
#   'Predicates': {'new_algorithm': [242], 'old_algorithm': [242]},
#   'Time_Check JUnit': {'new_algorithm': [9], 'old_algorithm': [2]},
#   'Time_Coverage Analysis': {'new_algorithm': [65], 'old_algorithm': [31]},
#   'Time_Done': {'new_algorithm': [1], 'old_algorithm': [7]},
#   'Time_Generating assertions': {'new_algorithm': [984],
#    'old_algorithm': [840]},
#   'Time_Initializing': {'new_algorithm': [174], 'old_algorithm': [214]},
#   'Time_Inlining': {'new_algorithm': [9], 'old_algorithm': [8]},
#   'Time_JUnit': {'new_algorithm': [34], 'old_algorithm': [59]},
#   'Time_Minimizing': {'new_algorithm': [246], 'old_algorithm': [313]},
#   'Time_Search': {'new_algorithm': [1966], 'old_algorithm': [1915]},
#   'Time_Statistics': {'new_algorithm': [43], 'old_algorithm': [71]},
#   'TotalNumberOfConstraints': {'new_algorithm': [2], 'old_algorithm': [0]},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [21],
#    'old_algorithm': [31]},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [0],
#    'old_algorithm': [0]},
#   'Total_Time': {'new_algorithm': [3631], 'old_algorithm': [3562]}},
#  'org.joda.time.format.DateTimeFormat': {'Coverage': {'new_algorithm': [],
#    'old_algorithm': []},
#   'AvgPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'Fitness': {'new_algorithm': [], 'old_algorithm': []},
#   'MaxPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'MinPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfPathsDiverged': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfPathsExplored': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfUNSATQueries': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [], 'old_algorithm': []},
#   'Predicates': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Check JUnit': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Coverage Analysis': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Done': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Generating assertions': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Initializing': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Inlining': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_JUnit': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Minimizing': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Search': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Statistics': {'new_algorithm': [], 'old_algorithm': []},
#   'TotalNumberOfConstraints': {'new_algorithm': [], 'old_algorithm': []},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [],
#    'old_algorithm': []},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [],
#    'old_algorithm': []},
#   'Total_Time': {'new_algorithm': [], 'old_algorithm': []}},
#  'org.jgrapht.alg.BellmanFordIterator': {'Coverage': {'new_algorithm': [],
#    'old_algorithm': []},
#   'AvgPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'Fitness': {'new_algorithm': [], 'old_algorithm': []},
#   'MaxPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'MinPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfPathsDiverged': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfPathsExplored': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfUNSATQueries': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [], 'old_algorithm': []},
#   'Predicates': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Check JUnit': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Coverage Analysis': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Done': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Generating assertions': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Initializing': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Inlining': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_JUnit': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Minimizing': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Search': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Statistics': {'new_algorithm': [], 'old_algorithm': []},
#   'TotalNumberOfConstraints': {'new_algorithm': [], 'old_algorithm': []},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [],
#    'old_algorithm': []},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [],
#    'old_algorithm': []},
#   'Total_Time': {'new_algorithm': [], 'old_algorithm': []}},
#  'org.apache.commons.math3.transform.FastFourierTransformer': {'Coverage': {'new_algorithm': [],
#    'old_algorithm': []},
#   'AvgPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'Fitness': {'new_algorithm': [], 'old_algorithm': []},
#   'MaxPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'MinPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfPathsDiverged': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfPathsExplored': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfUNSATQueries': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [], 'old_algorithm': []},
#   'Predicates': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Check JUnit': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Coverage Analysis': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Done': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Generating assertions': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Initializing': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Inlining': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_JUnit': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Minimizing': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Search': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Statistics': {'new_algorithm': [], 'old_algorithm': []},
#   'TotalNumberOfConstraints': {'new_algorithm': [], 'old_algorithm': []},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [],
#    'old_algorithm': []},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [],
#    'old_algorithm': []},
#   'Total_Time': {'new_algorithm': [], 'old_algorithm': []}},
#  'net.n3.nanoxml.XMLElement': {'Coverage': {'new_algorithm': [],
#    'old_algorithm': []},
#   'AvgPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'Fitness': {'new_algorithm': [], 'old_algorithm': []},
#   'MaxPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'MinPathConditionLength': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfPathsDiverged': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfPathsExplored': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfSATQueriesNumberOfUsefulNewTests': {'new_algorithm': [],
#    'old_algorithm': []},
#   'NumberOfTimeoutQueries': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfUNSATQueries': {'new_algorithm': [], 'old_algorithm': []},
#   'NumberOfUnusefulNewTests': {'new_algorithm': [], 'old_algorithm': []},
#   'Predicates': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Check JUnit': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Coverage Analysis': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Done': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Generating assertions': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Initializing': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Inlining': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_JUnit': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Minimizing': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Search': {'new_algorithm': [], 'old_algorithm': []},
#   'Time_Statistics': {'new_algorithm': [], 'old_algorithm': []},
#   'TotalNumberOfConstraints': {'new_algorithm': [], 'old_algorithm': []},
#   'TotalTimeSpentExecutingConcolicaly': {'new_algorithm': [],
#    'old_algorithm': []},
#   'TotalTimeSpentSolvingConstraints': {'new_algorithm': [],
#    'old_algorithm': []},
#   'Total_Time': {'new_algorithm': [], 'old_algorithm': []}}}

# %%
plt.plot(data["org.joda.time.format.DateTimeFormat"]["Total_Time"]["new_algorithm"])
plt.plot(data["org.joda.time.format.DateTimeFormat"]["Total_Time"]["old_algorithm"])
# plt.plot([1, 2, 3, 4])
# plt.ylabel('total_time comparissons for dateTimeFormat')
plt.show()
